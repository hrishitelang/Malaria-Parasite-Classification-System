# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score

# %%
cell_df = pd.read_csv('image_bins_all_color_GLCM.csv')
cell_df.head()
# Out:
#    Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7       rmean  \
# 0   5345     12      0      0      0     58      0  15601  119.403217
# 1   6582      2      0      0      0    130      0  13024  101.961800
# 2   7612      0      0      0     50    127      0  16419  101.725669
# 3   5145     12      0      0      0    259      0  13044  101.809534
# 4   4065      0      0      0      4    850      0   9815  112.723632
#
#         gmean  ...          var       asm     contrast  correlation       idm  \
# 0  118.740055  ...  2378.244684  0.009158  1211.821712     0.797017  0.525642
# 1  102.631320  ...  2231.711952  0.008901  1225.951925     0.784520  0.493865
# 2  100.764210  ...  2054.426557  0.006830  1165.783478     0.778996  0.464011
# 3   80.022914  ...  1567.735710  0.008009   668.185088     0.824332  0.499687
# 4   68.244401  ...  1557.136176  0.004084   890.222724     0.777694  0.468373
#
#     entropy  homogenity    energy  dissimilarity  Class
# ...

# %%
feature_df = cell_df[['Bins0','Bins1','Bins2','Bins3','Bins4', 'Bins5','Bins6','Bins7','rmean','gmean','bmean','rstd','gstd','bstd','rvar','gvar','bvar','var','asm','contrast','correlation','idm','entropy','homogenity','energy','dissimilarity']]
X = np.asarray(feature_df)
y = np.asarray(cell_df['Class'])

# %%
# Split the data into 40% test and 60% training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %%
# Create a random forest classifier
clf = RandomForestClassifier(n_estimators=10000, random_state=0, n_jobs=-1)

# Train the classifier
clf.fit(X_train, y_train)

# Print the name and gini importance of each feature
for feature in zip(feature_df, clf.feature_importances_):
    print(feature)
# Out:
# ('Bins0', 0.012990876301110479)
# ('Bins1', 0.0602781644752704)
# ('Bins2', 0.0015148233898243488)
# ('Bins3', 0.0008208447786152754)
# ('Bins4', 0.10910352181898172)
# ('Bins5', 0.4884146855663326)
# ('Bins6', 0.00540874704208587)
# ('Bins7', 0.014762362194282343)
# ('rmean', 0.011402462477911587)
# ('gmean', 0.019274643032362055)
# ('bmean', 0.009558987472399345)
# ('rstd', 0.008606646468671476)
# ('gstd', 0.008700515181348553)
# ('bstd', 0.008604671295909408)
# ('rvar', 0.011565734258570397)
# ('gvar', 0.0201618839913614)
# ('bvar', 0.008806190070532086)
# ('var', 0.012255461893650265)
# ('asm', 0.026615884512122087)
# ('contrast', 0.009822908919201944)
# ('correlation', 0.009319189086924211)
# ('idm', 0.008435528259829706)
# ('entropy', 0.09054758928633175)
# ('homogenity', 0.0084701364531239)
# ('energy', 0.026739098853559972)
# ('dissimilarity', 0.007818442919686856)

# %%
# Create a selector object that will use the random forest classifier to identify
# features that have an importance of more than 0.15
sfm = SelectFromModel(clf, threshold=0.15)

# Train the selector
sfm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-6b4892919e8f> in <module>
#       4
#       5 # Train the selector
# ----> 6 sfm.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_from_model.py in fit(self, X, y, **fit_params)
#     220                 "Since 'prefit=True', call transform directly")
#     221         self.estimator_ = clone(self.estimator)
# --> 222         self.estimator_.fit(X, y, **fit_params)
#     223         return self
#     224
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# ...

# %%
# Print the names of the most important features
for feature_list_index in sfm.get_support(indices=True):
    print(feat_labels[feature_list_index])
