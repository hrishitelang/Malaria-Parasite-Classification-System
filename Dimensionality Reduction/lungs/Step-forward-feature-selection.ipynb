# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score

from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
data = pd.read_csv('image_bins_stats.csv')
data.shape
# Out:
# (24000, 98)

# %%
data.head()
# Out:
#         filename  rmean_bins0  rmean_bins1  rmean_bins2  rmean_bins3  \
# 0  clean_p_1.jpg     1.485688   116.416667          0.0          0.0
# 1  clean_p_2.jpg     0.191129    91.000000          0.0          0.0
# 2  clean_p_3.jpg     1.218065   115.000000          0.0          0.0
# 3  clean_p_4.jpg     0.148524    98.000000          0.0          0.0
# 4  clean_p_5.jpg     0.183128     0.000000          0.0          0.0
#
#    rmean_bins4  rmean_bins5  rmean_bins6  rmean_bins7  rstd_bins0  ...  \
# 0     0.000000   128.758621          0.0   159.770015   11.472993  ...
# 1     0.000000   122.485714          0.0   149.839854    0.626280  ...
# 2   121.730769   135.517857          0.0   154.189458   10.132966  ...
# 3     0.000000   129.906667          0.0   157.583812    0.573290  ...
# 4     0.000000     0.000000          0.0   158.600042    0.602004  ...
#
#    bskew_bins7  bkurto_bins0  bkurto_bins1  bkurto_bins2  bkurto_bins3  \
# 0     7.358843     47.621590      3.092351           0.0           0.0
# 1     8.430080      7.154429      0.840896           0.0           0.0
# 2     7.949709     43.394240      0.420448           0.0           0.0
# 3     8.987692      6.601182      2.619225           0.0           0.0
# 4     7.204324      6.869720      0.000000           0.0           0.0
#
#    bkurto_bins4  bkurto_bins5  bkurto_bins6  bkurto_bins7  class
# 0      0.000000      8.421707           0.0      9.181035      1
# 1      0.000000     15.029039           0.0     10.516990      1
# 2      7.701832     13.599319           0.0     10.354453      1
# 3      0.000000     12.787280           0.0     10.943418      1
# 4      0.000000      0.000000           0.0      8.924785      1
#
# [5 rows x 98 columns]

# %%
data = data.drop(['filename'], axis=1)
data.head()
# Out:
#    rmean_bins0  rmean_bins1  rmean_bins2  rmean_bins3  rmean_bins4  \
# 0     1.485688   116.416667          0.0          0.0     0.000000
# 1     0.191129    91.000000          0.0          0.0     0.000000
# 2     1.218065   115.000000          0.0          0.0   121.730769
# 3     0.148524    98.000000          0.0          0.0     0.000000
# 4     0.183128     0.000000          0.0          0.0     0.000000
#
#    rmean_bins5  rmean_bins6  rmean_bins7  rstd_bins0  rstd_bins1  ...  \
# 0   128.758621          0.0   159.770015   11.472993    1.943118  ...
# 1   122.485714          0.0   149.839854    0.626280    0.000000  ...
# 2   135.517857          0.0   154.189458   10.132966    0.000000  ...
# 3   129.906667          0.0   157.583812    0.573290    2.000000  ...
# 4     0.000000          0.0   158.600042    0.602004    0.000000  ...
#
#    bskew_bins7  bkurto_bins0  bkurto_bins1  bkurto_bins2  bkurto_bins3  \
# 0     7.358843     47.621590      3.092351           0.0           0.0
# 1     8.430080      7.154429      0.840896           0.0           0.0
# 2     7.949709     43.394240      0.420448           0.0           0.0
# 3     8.987692      6.601182      2.619225           0.0           0.0
# 4     7.204324      6.869720      0.000000           0.0           0.0
#
#    bkurto_bins4  bkurto_bins5  bkurto_bins6  bkurto_bins7  class
# 0      0.000000      8.421707           0.0      9.181035      1
# 1      0.000000     15.029039           0.0     10.516990      1
# 2      7.701832     13.599319           0.0     10.354453      1
# 3      0.000000     12.787280           0.0     10.943418      1
# 4      0.000000      0.000000           0.0      8.924785      1
#
# [5 rows x 97 columns]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
_train, X_test, y_train, y_test = train_test_split(
    data.drop(labels=['class'], axis=1),
    data['class'],
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((16799, 96), (7200, 96))

# %%
# remove correlated features to reduce the feature space

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_train, 0.8)
print('correlated features: ', len(set(corr_features)) )
# Out:
# correlated features:  72

# %%
# remove correlated features
X_train.drop(labels=corr_features, axis=1, inplace=True)
X_test.drop(labels=corr_features, axis=1, inplace=True)

X_train.shape, X_test.shape
# Out:
# ((16799, 24), (7200, 24))

# %%
# within the SFS we indicate:

# 1) the algorithm we want to create, in this case RandomForests
# (note that I use few trees to speed things up)

# 2) the stopping criteria: want to select 10 features 

# 3) wheter to perform step forward or step backward

# 4) the evaluation metric: in this case the roc_auc
# 5) the cross-validation

# this is going to take a while, do not despair

sfs = SFS(RandomForestClassifier(n_estimators=10, n_jobs=4, random_state=0), 
           k_features=10, # the more features we want, the longer it will take to run
           forward=True, 
           floating=False, # see the docs for more details in this parameter
           verbose=2, # this indicates how much to print out intermediate steps
           scoring='roc_auc',
           cv=2)

sfs = sfs.fit(np.array(X_train), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   29.6s finished
#
# [2021-01-25 12:22:52] Features: 1/10 -- score: 0.9529459744359536[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   20.9s finished
#
# [2021-01-25 12:23:13] Features: 2/10 -- score: 0.9561391347892918[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   20.4s finished
#
# [2021-01-25 12:23:34] Features: 3/10 -- score: 0.9635170179235064[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   19.5s finished
#
# [2021-01-25 12:23:53] Features: 4/10 -- score: 0.9662021398869827[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   18.7s finished
#
# [2021-01-25 12:24:12] Features: 5/10 -- score: 0.9670699274445697[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   17.8s finished
#
# [2021-01-25 12:24:30] Features: 6/10 -- score: 0.9692569387422589[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   16.5s finished
#
# [2021-01-25 12:24:47] Features: 7/10 -- score: 0.9725832147367839[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   15.9s finished
#
# [2021-01-25 12:25:03] Features: 8/10 -- score: 0.9731921724794679[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   15.9s finished
#
# [2021-01-25 12:25:19] Features: 9/10 -- score: 0.9732670587437429[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   15.2s finished
#
# [2021-01-25 12:25:34] Features: 10/10 -- score: 0.9739212529655954

# %%
sfs = SFS(RandomForestClassifier(n_estimators=10, n_jobs=4, random_state=0), 
           k_features=10, # the more features we want, the longer it will take to run
           forward=True, 
           floating=False, # see the docs for more details in this parameter
           verbose=2, # this indicates how much to print out intermediate steps
           scoring='accuracy',
           cv=2)

sfs = sfs.fit(np.array(X_train), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   21.3s finished
#
# [2021-01-25 12:26:25] Features: 1/10 -- score: 0.940234594254418[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   19.8s finished
#
# [2021-01-25 12:26:45] Features: 2/10 -- score: 0.9436871949041552[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   20.6s finished
#
# [2021-01-25 12:27:06] Features: 3/10 -- score: 0.9464254389694918[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   18.5s finished
#
# [2021-01-25 12:27:24] Features: 4/10 -- score: 0.9477945716326773[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   17.5s finished
#
# [2021-01-25 12:27:42] Features: 5/10 -- score: 0.9484493406244507[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   16.5s finished
#
# [2021-01-25 12:27:58] Features: 6/10 -- score: 0.9499375846897873[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   17.5s finished
#
# [2021-01-25 12:28:16] Features: 7/10 -- score: 0.9504733344105591[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   17.8s finished
#
# [2021-01-25 12:28:34] Features: 8/10 -- score: 0.9498780679672749[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   15.4s finished
#
# [2021-01-25 12:28:50] Features: 9/10 -- score: 0.9503542797044999[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   14.2s finished
#
# [2021-01-25 12:29:04] Features: 10/10 -- score: 0.9502352604334983
