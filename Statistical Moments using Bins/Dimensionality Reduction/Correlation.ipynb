# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('image_bins_stats.csv')
data.shape
# Out:
# (24000, 98)

# %%
data.head()
# Out:
#         filename  rmean_bins0  rmean_bins1  rmean_bins2  rmean_bins3  \
# 0  clean_p_1.jpg     1.485688   116.416667          0.0          0.0
# 1  clean_p_2.jpg     0.191129    91.000000          0.0          0.0
# 2  clean_p_3.jpg     1.218065   115.000000          0.0          0.0
# 3  clean_p_4.jpg     0.148524    98.000000          0.0          0.0
# 4  clean_p_5.jpg     0.183128     0.000000          0.0          0.0
#
#    rmean_bins4  rmean_bins5  rmean_bins6  rmean_bins7  rstd_bins0  ...  \
# 0     0.000000   128.758621          0.0   159.770015   11.472993  ...
# 1     0.000000   122.485714          0.0   149.839854    0.626280  ...
# 2   121.730769   135.517857          0.0   154.189458   10.132966  ...
# 3     0.000000   129.906667          0.0   157.583812    0.573290  ...
# 4     0.000000     0.000000          0.0   158.600042    0.602004  ...
#
#    bskew_bins7  bkurto_bins0  bkurto_bins1  bkurto_bins2  bkurto_bins3  \
# 0     7.358843     47.621590      3.092351           0.0           0.0
# 1     8.430080      7.154429      0.840896           0.0           0.0
# 2     7.949709     43.394240      0.420448           0.0           0.0
# 3     8.987692      6.601182      2.619225           0.0           0.0
# 4     7.204324      6.869720      0.000000           0.0           0.0
#
#    bkurto_bins4  bkurto_bins5  bkurto_bins6  bkurto_bins7  class
# 0      0.000000      8.421707           0.0      9.181035      1
# 1      0.000000     15.029039           0.0     10.516990      1
# 2      7.701832     13.599319           0.0     10.354453      1
# 3      0.000000     12.787280           0.0     10.943418      1
# 4      0.000000      0.000000           0.0      8.924785      1
#
# [5 rows x 98 columns]

# %%
data = data.drop(['filename'], axis=1)

# %%
data.head()
# Out:
#    rmean_bins0  rmean_bins1  rmean_bins2  rmean_bins3  rmean_bins4  \
# 0     1.485688   116.416667          0.0          0.0     0.000000
# 1     0.191129    91.000000          0.0          0.0     0.000000
# 2     1.218065   115.000000          0.0          0.0   121.730769
# 3     0.148524    98.000000          0.0          0.0     0.000000
# 4     0.183128     0.000000          0.0          0.0     0.000000
#
#    rmean_bins5  rmean_bins6  rmean_bins7  rstd_bins0  rstd_bins1  ...  \
# 0   128.758621          0.0   159.770015   11.472993    1.943118  ...
# 1   122.485714          0.0   149.839854    0.626280    0.000000  ...
# 2   135.517857          0.0   154.189458   10.132966    0.000000  ...
# 3   129.906667          0.0   157.583812    0.573290    2.000000  ...
# 4     0.000000          0.0   158.600042    0.602004    0.000000  ...
#
#    bskew_bins7  bkurto_bins0  bkurto_bins1  bkurto_bins2  bkurto_bins3  \
# 0     7.358843     47.621590      3.092351           0.0           0.0
# 1     8.430080      7.154429      0.840896           0.0           0.0
# 2     7.949709     43.394240      0.420448           0.0           0.0
# 3     8.987692      6.601182      2.619225           0.0           0.0
# 4     7.204324      6.869720      0.000000           0.0           0.0
#
#    bkurto_bins4  bkurto_bins5  bkurto_bins6  bkurto_bins7  class
# 0      0.000000      8.421707           0.0      9.181035      1
# 1      0.000000     15.029039           0.0     10.516990      1
# 2      7.701832     13.599319           0.0     10.354453      1
# 3      0.000000     12.787280           0.0     10.943418      1
# 4      0.000000      0.000000           0.0      8.924785      1
#
# [5 rows x 97 columns]

# %%
import numpy as np
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

clean_dataset(data)
# Out:
#        rmean_bins0  rmean_bins1  rmean_bins2  rmean_bins3  rmean_bins4  \
# 0         1.485688   116.416667          0.0          0.0     0.000000
# 1         0.191129    91.000000          0.0          0.0     0.000000
# 2         1.218065   115.000000          0.0          0.0   121.730769
# 3         0.148524    98.000000          0.0          0.0     0.000000
# 4         0.183128     0.000000          0.0          0.0     0.000000
# ...            ...          ...          ...          ...          ...
# 23994     0.167535     0.000000          0.0          0.0     0.000000
# 23995     0.182460     0.000000          0.0          0.0     0.000000
# 23996     0.222222     0.000000          0.0          0.0     0.000000
# 23997     0.217425     0.000000          0.0          0.0     0.000000
# 23998     0.226175     0.000000          0.0          0.0     0.000000
#
#        rmean_bins5  rmean_bins6  rmean_bins7  rstd_bins0  rstd_bins1  ...  \
# 0       128.758621     0.000000   159.770015   11.472993    1.943118  ...
# 1       122.485714     0.000000   149.839854    0.626280    0.000000  ...
# 2       135.517857     0.000000   154.189458   10.132966    0.000000  ...
# 3       129.906667     0.000000   157.583812    0.573290    2.000000  ...
# 4         0.000000     0.000000   158.600042    0.602004    0.000000  ...
# ...            ...          ...          ...         ...         ...  ...
# 23994     0.000000     0.000000   145.580835    0.587364    0.000000  ...
# 23995     0.000000     0.000000   142.290042    0.590877    0.000000  ...
# 23996     0.000000     0.000000   145.978772    0.689536    0.000000  ...
# 23997     0.000000     0.000000   145.915418    0.665380    0.000000  ...
# 23998     0.000000   114.428571   144.317780    0.689573    0.000000  ...
#
#        bskew_bins7  bkurto_bins0  bkurto_bins1  bkurto_bins2  bkurto_bins3  \
# 0         7.358843     47.621590      3.092351           0.0           0.0
# 1         8.430080      7.154429      0.840896           0.0           0.0
# 2         7.949709     43.394240      0.420448           0.0           0.0
# 3         8.987692      6.601182      2.619225           0.0           0.0
# 4         7.204324      6.869720      0.000000           0.0           0.0
# ...            ...           ...           ...           ...           ...
# 23994     6.817875      7.277478      0.000000           0.0           0.0
# 23995     5.262551      8.170191      0.000000           0.0           0.0
# 23996     5.407731      7.859719      0.000000           0.0           0.0
# 23997     5.073114      7.887594      0.000000           0.0           0.0
# 23998     7.435542      7.406609      0.000000           0.0           0.0
#
#        bkurto_bins4  bkurto_bins5  bkurto_bins6  bkurto_bins7  class
# 0          0.000000      8.421707      0.000000      9.181035    1.0
# 1          0.000000     15.029039      0.000000     10.516990    1.0
# 2          7.701832     13.599319      0.000000     10.354453    1.0
# 3          0.000000     12.787280      0.000000     10.943418    1.0
# 4          0.000000      0.000000      0.000000      8.924785    1.0
# ...             ...           ...           ...           ...    ...
# 23994      0.000000      0.000000      0.000000     11.111529    0.0
# 23995      0.000000      0.000000      0.000000     10.111068    0.0
# 23996      0.000000      0.000000      0.000000      9.734824    0.0
# 23997      0.000000      0.000000      0.000000      9.672132    0.0
# 23998      0.000000      0.000000     14.278229     11.305344    0.0
#
# [23999 rows x 97 columns]

# %%
# separate train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(labels=['class'], axis=1),
    data['class'],
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((16799, 96), (7200, 96))

# %%
# visualise correlated features:

# I will build a correlation matrix, which examines the 
# correlation of all features (that is, for all possible feature combinations)
# and then visualise the correlation matrix using a heatmap

# the default correlation method of pandas.corr is pearson
# I include it anyways for the demo
corrmat = X_train.corr(method='pearson')

# we can make a heatmap with the package seaborn
# and customise the colours of searborn's heatmap
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# some more parameters for the figure
fig, ax = plt.subplots()
fig.set_size_inches(11,11)

# and now plot the correlation matrix
sns.heatmap(corrmat, cmap=cmap)

# %%
# build a dataframe with the correlation between features
# remember that the absolute value of the correlation
# coefficient is important and not the sign

corrmat = X_train.corr()
corrmat = corrmat.abs().unstack() # absolute value of corr coef
corrmat = corrmat.sort_values(ascending=False)
corrmat = corrmat[corrmat >= 0.8]
corrmat = corrmat[corrmat < 1]
corrmat = pd.DataFrame(corrmat).reset_index()
corrmat.columns = ['feature1', 'feature2', 'corr']
corrmat.head()
# Out:
#        feature1      feature2      corr
# 0   rskew_bins3  rkurto_bins3  0.999641
# 1  rkurto_bins3   rskew_bins3  0.999641
# 2   rskew_bins4  rkurto_bins4  0.999470
# 3  rkurto_bins4   rskew_bins4  0.999470
# 4  rkurto_bins2   rskew_bins2  0.999460

# %%
# find groups of correlated features

grouped_feature_ls = []
correlated_groups = []

for feature in corrmat.feature1.unique():
    
    if feature not in grouped_feature_ls:

        # find all features correlated to a single feature
        correlated_block = corrmat[corrmat.feature1 == feature]
        grouped_feature_ls = grouped_feature_ls + list(
            correlated_block.feature2.unique()) + [feature]

        # append the block of features to the list
        correlated_groups.append(correlated_block)

print('found {} correlated groups'.format(len(correlated_groups)))
print('out of {} total features'.format(X_train.shape[1]))
# Out:
# found 21 correlated groups
# out of 96 total features

# %%
# now we can print out each group. We see that some groups contain
# only 2 correlated features, some other groups present several features 
# that are correlated among themselves.

for group in correlated_groups:
    print(group)
    print()
# Out:
#         feature1      feature2      corr
# 0    rskew_bins3  rkurto_bins3  0.999641
# 15   rskew_bins3    rstd_bins3  0.999271
# 426  rskew_bins3   bskew_bins3  0.838694
# 429  rskew_bins3    bstd_bins3  0.838481
# 441  rskew_bins3  bkurto_bins3  0.829427
# 497  rskew_bins3    gstd_bins3  0.801997
#
#         feature1      feature2      corr
# 2    rskew_bins4  rkurto_bins4  0.999470
# 27   rskew_bins4    rstd_bins4  0.998989
# 320  rskew_bins4    gstd_bins4  0.866748
# 331  rskew_bins4  gkurto_bins4  0.864690
# 333  rskew_bins4   gskew_bins4  0.864497
# 349  rskew_bins4  bkurto_bins4  0.859824
# 354  rskew_bins4   bskew_bins4  0.858729
# 368  rskew_bins4    bstd_bins4  0.856214
# 469  rskew_bins4   rmean_bins4  0.809383
#
#          feature1      feature2      corr
# 4    rkurto_bins2   rskew_bins2  0.999460
# 86   rkurto_bins2    rstd_bins2  0.996647
# 358  rkurto_bins2    bstd_bins2  0.858356
# 377  rkurto_bins2  bkurto_bins2  0.854159
# 384  rkurto_bins2   bskew_bins2  0.852439
#
#         feature1      feature2      corr
# 6    gskew_bins3  gkurto_bins3  0.999427
# 32   gskew_bins3    gstd_bins3  0.998873
# 463  gskew_bins3   bskew_bins3  0.810918
# 482  gskew_bins3    bstd_bins3  0.806406
#
#          feature1      feature2      corr
# 8    rkurto_bins1   rskew_bins1  0.999408
# 88   rkurto_bins1    rstd_bins1  0.996627
# 239  rkurto_bins1    bstd_bins1  0.901160
# 248  rkurto_bins1  bkurto_bins1  0.900561
# 257  rkurto_bins1   bskew_bins1  0.899807
#
#         feature1      feature2      corr
# 10   rskew_bins6  rkurto_bins6  0.999277
# 56   rskew_bins6    rstd_bins6  0.998511
# 174  rskew_bins6    gstd_bins6  0.941283
# 176  rskew_bins6  gkurto_bins6  0.940922
# 185  rskew_bins6   gskew_bins6  0.940168
# 409  rskew_bins6   bskew_bins6  0.844943
# 419  rskew_bins6    bstd_bins6  0.843255
# 424  rskew_bins6  bkurto_bins6  0.840832
#
#          feature1      feature2      corr
# 12   gkurto_bins5   gskew_bins5  0.999276
# 85   gkurto_bins5    gstd_bins5  0.996700
# 210  gkurto_bins5   bskew_bins5  0.917503
# 212  gkurto_bins5    bstd_bins5  0.917469
# 221  gkurto_bins5  bkurto_bins5  0.914427
# 244  gkurto_bins5  rkurto_bins5  0.900708
# 254  gkurto_bins5   rskew_bins5  0.900150
# 264  gkurto_bins5    rstd_bins5  0.898053
# 444  gkurto_bins5   rmean_bins5  0.822503
# 480  gkurto_bins5   bmean_bins5  0.806846
#
#          feature1     feature2      corr
# 22   gkurto_bins1  gskew_bins1  0.999091
# 110  gkurto_bins1   gstd_bins1  0.995192
#
#        feature1      feature2      corr
# 28  gskew_bins2  gkurto_bins2  0.998932
# 70  gskew_bins2    gstd_bins2  0.997803
#
#        feature1     feature2      corr
# 68  gmean_bins6  rmean_bins6  0.997947
#
#        feature1     feature2      corr
# 78  gmean_bins2  rmean_bins2  0.997115
#
#         feature1     feature2      corr
# 108  rmean_bins3  gmean_bins3  0.995305
#
#          feature1      feature2      corr
# 114  rkurto_bins0   rskew_bins0  0.992558
# 156  rkurto_bins0  bkurto_bins0  0.948371
# 182  rkurto_bins0    rstd_bins0  0.940272
# 197  rkurto_bins0   bskew_bins0  0.933770
# 199  rkurto_bins0  gkurto_bins0  0.932703
# 204  rkurto_bins0   gskew_bins0  0.926495
# 299  rkurto_bins0    gstd_bins0  0.878520
# 365  rkurto_bins0    bstd_bins0  0.857434
#
#          feature1     feature2      corr
# 116  rkurto_bins7  rskew_bins7  0.990920
# 169  rkurto_bins7   rstd_bins7  0.945802
#
#         feature1      feature2      corr
# 146  gskew_bins7  gkurto_bins7  0.963076
# 155  gskew_bins7    gstd_bins7  0.952811
# 453  gskew_bins7   bskew_bins7  0.817776
#
#         feature1     feature2      corr
# 153  gmean_bins5  rmean_bins5  0.956159
# 380  gmean_bins5  bmean_bins5  0.853589
#
#         feature1     feature2      corr
# 158  gmean_bins1  rmean_bins1  0.947434
#
#        feature1      feature2      corr
# 166  bstd_bins7  bkurto_bins7  0.946229
# 192  bstd_bins7   bskew_bins7  0.935674
#
#         feature1     feature2      corr
# 259  gmean_bins0   gstd_bins0  0.899069
# 310  gmean_bins0  rmean_bins0  0.873097
# 353  gmean_bins0   rstd_bins0  0.859432
# 397  gmean_bins0   bstd_bins0  0.849162
#
#         feature1     feature2     corr
# 261  gmean_bins4  rmean_bins4  0.89903
#
#         feature1     feature2      corr
# 455  bmean_bins4  rmean_bins4  0.816921

# %%
# we can now investigate further features within one group.
# let's for example select group 1

group = correlated_groups[1]
group
# Out:
#         feature1      feature2      corr
# 2    rskew_bins4  rkurto_bins4  0.999470
# 27   rskew_bins4    rstd_bins4  0.998989
# 320  rskew_bins4    gstd_bins4  0.866748
# 331  rskew_bins4  gkurto_bins4  0.864690
# 333  rskew_bins4   gskew_bins4  0.864497
# 349  rskew_bins4  bkurto_bins4  0.859824
# 354  rskew_bins4   bskew_bins4  0.858729
# 368  rskew_bins4    bstd_bins4  0.856214
# 469  rskew_bins4   rmean_bins4  0.809383

# %%
from sklearn.ensemble import RandomForestClassifier

# add all features of the group to a list
features = list(group['feature2'].unique())+['rskew_bins4']

# train a random forest 
rf = RandomForestClassifier(n_estimators=200, random_state=39, max_depth=4)
rf.fit(X_train[features].fillna(0), y_train)
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=200, random_state=39)

# %%
# get the feature importance attributed by the 
# random forest model (more on this in coming lectures)

importance = pd.concat(
    [pd.Series(features),
     pd.Series(rf.feature_importances_)], axis=1)

importance.columns = ['feature', 'importance']

# sort features by importance, most important first
importance.sort_values(by='importance', ascending=False)
# Out:
#         feature  importance
# 8   rmean_bins4    0.400081
# 4   gskew_bins4    0.208988
# 2    gstd_bins4    0.147685
# 3  gkurto_bins4    0.125166
# 0  rkurto_bins4    0.036029
# 9   rskew_bins4    0.035851
# 1    rstd_bins4    0.031458
# 6   bskew_bins4    0.013504
# 7    bstd_bins4    0.000644
# 5  bkurto_bins4    0.000594

# %%
# BONUS:
# let's plot the correlation of the features in the correlated group from the
# previous cell

for feature in group['feature1']:
    plt.scatter(X_train['rkurto_bins3'], X_train[feature])
    plt.xlabel('rkurto_bins2')
    plt.ylabel(feature)
    plt.show()
