# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bins = pd.read_csv("image_bins_all.csv")

# %%
bins.head()
# Out:
#         filename  Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7  \
# 0  clean_p_1.jpg   5345     12      0      0      0     58      0  15601
# 1  clean_p_2.jpg  10935      2      0      0      0    140      0  19707
# 2  clean_p_3.jpg   5292      2      0      0     26     56      0  15613
# 3  clean_p_4.jpg   7992      4      0      0      0    225      0  14109
# 4  clean_p_5.jpg   6318      0      0      0      0      0      0  14164
#
#    Class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
bins['Class'] = bins['Class'].astype('category')

# %%
bins['Class'] = bins['Class'].replace(1, 'Parasitized')

# %%
bins['Class'] = bins['Class'].replace(0, 'Uninfected')

# %%
bins.drop(['filename'], axis=1, inplace=True)

# %%
bins.head()
# Out:
#    Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7        Class
# 0   5345     12      0      0      0     58      0  15601  Parasitized
# 1  10935      2      0      0      0    140      0  19707  Parasitized
# 2   5292      2      0      0     26     56      0  15613  Parasitized
# 3   7992      4      0      0      0    225      0  14109  Parasitized
# 4   6318      0      0      0      0      0      0  14164  Parasitized

# %%
bins.tail()
# Out:
#        Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7       Class
# 23995   7503      0      0      0      0      0      0  17563  Uninfected
# 23996   6435      0      0      0      0      0      0  14509  Uninfected
# 23997   6462      0      0      0      0      0      0  14944  Uninfected
# 23998   6747      0      0      0      0      0      7  13566  Uninfected
# 23999   5241      0      0      0      0      0      0  13555  Uninfected

# %%
bins.plot(figsize = (20, 10))

# %%
df1 = bins.copy()

# %%
df1
# Out:
#        Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7        Class
# 0       5345     12      0      0      0     58      0  15601  Parasitized
# 1      10935      2      0      0      0    140      0  19707  Parasitized
# 2       5292      2      0      0     26     56      0  15613  Parasitized
# 3       7992      4      0      0      0    225      0  14109  Parasitized
# 4       6318      0      0      0      0      0      0  14164  Parasitized
# ...      ...    ...    ...    ...    ...    ...    ...    ...          ...
# 23995   7503      0      0      0      0      0      0  17563   Uninfected
# 23996   6435      0      0      0      0      0      0  14509   Uninfected
# 23997   6462      0      0      0      0      0      0  14944   Uninfected
# 23998   6747      0      0      0      0      0      7  13566   Uninfected
# 23999   5241      0      0      0      0      0      0  13555   Uninfected
#
# [24000 rows x 9 columns]

# %%
df1['Bins0'] = df1['Bins0'].cumsum()
df1['Bins1'] = df1['Bins1'].cumsum()
df1['Bins2'] = df1['Bins2'].cumsum()
df1['Bins3'] = df1['Bins3'].cumsum()
df1['Bins4'] = df1['Bins4'].cumsum()
df1['Bins5'] = df1['Bins5'].cumsum()
df1['Bins6'] = df1['Bins6'].cumsum()
df1['Bins7'] = df1['Bins7'].cumsum()
df1.head()
# Out:
#    Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7        Class
# 0   5345     12      0      0      0     58      0  15601  Parasitized
# 1  16280     14      0      0      0    198      0  35308  Parasitized
# 2  21572     16      0      0     26    254      0  50921  Parasitized
# 3  29564     20      0      0     26    479      0  65030  Parasitized
# 4  35882     20      0      0     26    479      0  79194  Parasitized

# %%
df1.tail()
# Out:
#            Bins0  Bins1  Bins2  Bins3   Bins4    Bins5  Bins6      Bins7  \
# 23995  120504261  72941    707   2127  209658  2151251   8097  298522175
# 23996  120510696  72941    707   2127  209658  2151251   8097  298536684
# 23997  120517158  72941    707   2127  209658  2151251   8097  298551628
# 23998  120523905  72941    707   2127  209658  2151251   8104  298565194
# 23999  120529146  72941    707   2127  209658  2151251   8104  298578749
#
#             Class
# 23995  Uninfected
# 23996  Uninfected
# 23997  Uninfected
# 23998  Uninfected
# 23999  Uninfected

# %%
df1.plot(figsize = (20, 10))

# %%
df1.plot(figsize = (20, 10), logy = True)

# %%
df1.plot(figsize = (20, 10), logx = True)

# %%
bins
# Out:
#        Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7        Class
# 0       5345     12      0      0      0     58      0  15601  Parasitized
# 1      10935      2      0      0      0    140      0  19707  Parasitized
# 2       5292      2      0      0     26     56      0  15613  Parasitized
# 3       7992      4      0      0      0    225      0  14109  Parasitized
# 4       6318      0      0      0      0      0      0  14164  Parasitized
# ...      ...    ...    ...    ...    ...    ...    ...    ...          ...
# 23995   7503      0      0      0      0      0      0  17563   Uninfected
# 23996   6435      0      0      0      0      0      0  14509   Uninfected
# 23997   6462      0      0      0      0      0      0  14944   Uninfected
# 23998   6747      0      0      0      0      0      7  13566   Uninfected
# 23999   5241      0      0      0      0      0      0  13555   Uninfected
#
# [24000 rows x 9 columns]

# %%
df2 = bins.copy()
df2 = df2.drop(['Class'], axis = 1)

# %%
df2.head()
# Out:
#    Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7
# 0   5345     12      0      0      0     58      0  15601
# 1  10935      2      0      0      0    140      0  19707
# 2   5292      2      0      0     26     56      0  15613
# 3   7992      4      0      0      0    225      0  14109
# 4   6318      0      0      0      0      0      0  14164

# %%
df2.tail()
# Out:
#        Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7
# 23995   7503      0      0      0      0      0      0  17563
# 23996   6435      0      0      0      0      0      0  14509
# 23997   6462      0      0      0      0      0      0  14944
# 23998   6747      0      0      0      0      0      7  13566
# 23999   5241      0      0      0      0      0      0  13555

# %%
df2.iloc[0]
# Out:
# Bins0     5345
# Bins1       12
# Bins2        0
# Bins3        0
# Bins4        0
# Bins5       58
# Bins6        0
# Bins7    15601
# Name: 0, dtype: int64

# %%
df2.iloc[0].plot(kind = 'bar')

# %%
df2 = bins.iloc[:20, :]

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.barh(stacked = True)

# %%
bins.plot.hist() #Concentration of the legend based on the plots
#Checks how these values are concentrated around that number
#Lines are getting overlapped, so to get better idea, we use
#histogram with stacked plots to see all the plots

# %%
bins.plot(kind = 'hist', bins = 8, stacked=True)

# %%
bins['Bins0'].plot(kind = 'hist', bins=100)

# %%
bins['Bins1'].plot(kind = 'hist', bins=8, color='r')

# %%
bins['Bins2'].plot(kind = 'hist', bins=3, color='g')

# %%
bins['Bins3'].plot(kind = 'hist', bins=3, color='c')

# %%
bins['Bins4'].plot(kind = 'hist', bins=4, color='m')

# %%
bins['Bins5'].plot(kind = 'hist', bins=4, color='y')

# %%
bins['Bins6'].plot(kind = 'hist', bins=2, color='k')

# %%
bins['Bins7'].plot(kind = 'hist', bins=100, color='r')

# %%
bins.plot(kind = 'box', figsize = (15, 10), logx=True)

# %%
bins.describe()
# Out:
#               Bins0         Bins1         Bins2         Bins3         Bins4  \
# count  24000.000000  24000.000000  24000.000000  24000.000000  24000.000000
# mean    5022.047750      3.039208      0.029458      0.088625      8.735750
# std     2177.326521     16.352889      0.598976      3.526016     29.984248
# min      693.000000      0.000000      0.000000      0.000000      0.000000
# 25%     3730.750000      0.000000      0.000000      0.000000      0.000000
# 50%     4569.000000      0.000000      0.000000      0.000000      0.000000
# 75%     5700.000000      0.000000      0.000000      0.000000      1.000000
# max    57620.000000    883.000000     61.000000    305.000000   1745.000000
#
#               Bins5         Bins6         Bins7
# count  24000.000000  24000.000000  24000.000000
# mean      89.635458      0.337667  12440.781208
# std      177.623651      4.120561   2827.109773
# min        0.000000      0.000000   1183.000000
# 25%        0.000000      0.000000  10600.000000
# 50%        0.000000      0.000000  12376.000000
# 75%      133.000000      0.000000  14185.000000
# max     5006.000000    445.000000  33725.000000

# %%
sns.pairplot(bins)

# %%
df3 = bins.copy()

# %%
import numpy as np
df3['log_Bins0'] = np.log10(df3['Bins0'])
df3['log_Bins1'] = np.log10(df3['Bins1'])
df3['log_Bins2'] = np.log10(df3['Bins2'])
df3['log_Bins3'] = np.log10(df3['Bins3'])
df3['log_Bins4'] = np.log10(df3['Bins4'])
df3['log_Bins5'] = np.log10(df3['Bins5'])
df3['log_Bins6'] = np.log10(df3['Bins6'])
df3['log_Bins7'] = np.log10(df3['Bins7'])

df3 = df3.drop(columns = ['Bins0', 'Bins1','Bins2','Bins3','Bins4', 'Bins5','Bins6', 'Bins7'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df3
# Out:
#              Class  log_Bins0  log_Bins1  log_Bins2  log_Bins3  log_Bins4  \
# 0      Parasitized   3.727948   1.079181       -inf       -inf       -inf
# 1      Parasitized   4.038819   0.301030       -inf       -inf       -inf
# 2      Parasitized   3.723620   0.301030       -inf       -inf   1.414973
# 3      Parasitized   3.902655   0.602060       -inf       -inf       -inf
# 4      Parasitized   3.800580       -inf       -inf       -inf       -inf
# ...            ...        ...        ...        ...        ...        ...
# 23995   Uninfected   3.875235       -inf       -inf       -inf       -inf
# 23996   Uninfected   3.808549       -inf       -inf       -inf       -inf
# 23997   Uninfected   3.810367       -inf       -inf       -inf       -inf
# 23998   Uninfected   3.829111       -inf       -inf       -inf       -inf
# 23999   Uninfected   3.719414       -inf       -inf       -inf       -inf
#
#        log_Bins5  log_Bins6  log_Bins7
# 0       1.763428       -inf   4.193152
# 1       2.146128       -inf   4.294621
# 2       1.748188       -inf   4.193486
# 3       2.352183       -inf   4.149496
# 4           -inf       -inf   4.151186
# ...          ...        ...        ...
# 23995       -inf       -inf   4.244599
# 23996       -inf       -inf   4.161637
# 23997       -inf       -inf   4.174467
# 23998       -inf   0.845098   4.132452
# 23999       -inf       -inf   4.132100
#
# [24000 rows x 9 columns]

# %%
df3 = df3.drop(columns = ['Class'])

# %%
df3['Class'] = bins['Class']
df3
# Out:
#        log_Bins0  log_Bins1  log_Bins2  log_Bins3  log_Bins4  log_Bins5  \
# 0       3.727948   1.079181       -inf       -inf       -inf   1.763428
# 1       4.038819   0.301030       -inf       -inf       -inf   2.146128
# 2       3.723620   0.301030       -inf       -inf   1.414973   1.748188
# 3       3.902655   0.602060       -inf       -inf       -inf   2.352183
# 4       3.800580       -inf       -inf       -inf       -inf       -inf
# ...          ...        ...        ...        ...        ...        ...
# 23995   3.875235       -inf       -inf       -inf       -inf       -inf
# 23996   3.808549       -inf       -inf       -inf       -inf       -inf
# 23997   3.810367       -inf       -inf       -inf       -inf       -inf
# 23998   3.829111       -inf       -inf       -inf       -inf       -inf
# 23999   3.719414       -inf       -inf       -inf       -inf       -inf
#
#        log_Bins6  log_Bins7        Class
# 0           -inf   4.193152  Parasitized
# 1           -inf   4.294621  Parasitized
# 2           -inf   4.193486  Parasitized
# 3           -inf   4.149496  Parasitized
# 4           -inf   4.151186  Parasitized
# ...          ...        ...          ...
# 23995       -inf   4.244599   Uninfected
# 23996       -inf   4.161637   Uninfected
# 23997       -inf   4.174467   Uninfected
# 23998   0.845098   4.132452   Uninfected
# 23999       -inf   4.132100   Uninfected
#
# [24000 rows x 9 columns]

# %%
sns.pairplot(df3, hue="Class")
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot("log_Bins0", "log_Bins7", data=df3, kind="reg")

# %%
corr = bins.corr(method = 'pearson')
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(10, 275)

sns.heatmap(corr, cmap=cmap, square=True, linewidths=0.5, cbar_kws={"shrink": 0.5}, ax=ax, annot=True)

# %%
corr = df3.corr(method = 'pearson')
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(10, 275)

sns.heatmap(corr, cmap=cmap, square=True, linewidths=0.5, cbar_kws={"shrink": 0.5}, ax=ax, annot=True)

# %%
from scipy.stats import pearsonr
x = df3['log_Bins0'][:]
y = df3['log_Bins7'][:]
cor1,_ = pearsonr(x, y)
print(f'Pearson co-efficient of Bins 0 and Bins 7: {cor1}')
# Out:
# Pearson co-efficient of Bins 0 and Bins 7: 0.6546980329027086

# %%
df3.plot.hexbin(x='log_Bins0', y='log_Bins7', gridsize=10)
#Values of labels and colors are all plotted wrt c

# %%
df3 = bins.copy()

# %%
df3
# Out:
#        Bins0  Bins1  Bins2  Bins3  Bins4  Bins5  Bins6  Bins7        Class
# 0       5345     12      0      0      0     58      0  15601  Parasitized
# 1      10935      2      0      0      0    140      0  19707  Parasitized
# 2       5292      2      0      0     26     56      0  15613  Parasitized
# 3       7992      4      0      0      0    225      0  14109  Parasitized
# 4       6318      0      0      0      0      0      0  14164  Parasitized
# ...      ...    ...    ...    ...    ...    ...    ...    ...          ...
# 23995   7503      0      0      0      0      0      0  17563   Uninfected
# 23996   6435      0      0      0      0      0      0  14509   Uninfected
# 23997   6462      0      0      0      0      0      0  14944   Uninfected
# 23998   6747      0      0      0      0      0      7  13566   Uninfected
# 23999   5241      0      0      0      0      0      0  13555   Uninfected
#
# [24000 rows x 9 columns]

# %%
df3.drop(['Class'], axis=1, inplace=True)

# %%
df3.iloc[0].plot.pie(figsize = (5,5))

# %%
df3.iloc[12001].plot.pie(figsize = (5,5))

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(bins, figsize=(20,20), diagonal = 'kde', color='r')
plt.show()
